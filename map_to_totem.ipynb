# %%
import json
from collections import defaultdict
from pathlib import Path

import ifcopenshell
import ifcopenshell.util.classification
import pandas as pd

from utils import get_name, get_reference

# %%
element_types = json.loads(Path("TotemDatabase/ElementTypes.json").read_text())
element_types = [e["elementType"] for e in element_types]
element_types[0]
# Out:
# {'id': 'ET304746',
#  'names': {'en': 'FoG_Cast in situ_Reinforced concrete_LIB_New_01',
#   'fr': 'PS_Coulé sur site_Béton armé_BIB_Neuf_01',
#   'nl': 'VG_Ter plaatse gestort_Gewapend beton_BIB_Nieuw_01',
#   'de': 'not available'},
#  'description': {'en': 'Cast in situ_Reinforced concrete (150 mm) | Foam_PUR (130 mm) | Rigid tiles_Glazed ceramic',
#   'fr': 'Coulé sur site_Béton armé (150 mm) | Mousse_PUR (130 mm) | Carreaux rigides_Céramique émaillée',
#   'nl': 'Ter plaatse gestort_Gewapend beton (150 mm) | Schuim_PUR (130 mm) | Harde tegels_Geglazuurd keramiek',
#   'de': 'Cast in situ_Reinforced concrete (150 mm) | Foam_PUR (130 mm) | Rigid tiles_Glazed ceramic'},
#  'reference': '(13.)+',
#  'elementCategoryId': 'EC7',
#  'backendId': 1,
#  'uvalue': 0.202001,
#  'biogenicCarbonContent': 0.0,
#  'thickness': '0.472200000000',
#  'environmentalCost': 30.8793,
#  'environmentalCostMaterial': 26.4766608,
#  'environmentalCostEnergy': 4.4027,
#  'signature': 'ZOiDY3f6vIei/4MPHu7whA3yu3y3BDP+J8T/eZb4Tjk=',
#  'compositionSignature': 's9Lx4+UHgBpAvkOWJRJV6xze3XCpzS00Ru/Wiz/MF7M=',
#  'filterIds': '60|62|64',
#  'calculationModelVersion': '20 - 20230705',
#  'dimensionalParameterId': '79',
#  'newElementType': False,
#  'lifetimeFromEpd': False,
#  'createLogin': {'id': 'U1',
#   'email': 'sst@hemmis.be',
#   'firstname': 'Sofie',
#   'lastname': 'Struyve',
#   'language': 'nl',
#   'organisation': '',
#   'phone': '',
#   'admin': True,
#   'expert': False,
#   'needsToAcceptPolicy': False,
#   'newsletter': False,
#   'unconfirmedEmail': 'something.wrong@hemmis.be',
#   'profession': 'OTHER',
#   'otherProfession': 'Developer',
#   'lcaLicense': 'NONE',
#   'otherLcaLicense': None,
#   'role': 'ADMINISTRATOR',
#   'address': 'Otegemstraat 50\n8550 Zwevegem',
#   'allImportExportAllowed': False},
#  'modifLogin': None,
#  'createTimestamp': '20230706080456171',
#  'modifTimestamp': None,
#  'layers': [{'id': 'L1630672',
#    'sequence': 0,
#    'environmentalCost': None,
#    'rvalue': 0.0,
#    'sublayers': [{'id': 'SL1725263',
#      'sequence': 0,
#      'parameter1': '0.300000000000',
#      'parameter2': '1.000000000000',
#      'lambda': None,
#      'partId': 'WS1',
#      'status': 'NEW',
#      'delta': None,
#      'environmentalCost': 0.0216725,
#      'layered': False}]},
#   {'id': 'L1630673',
#    'sequence': 1,
#    'environmentalCost': None,
#    'rvalue': 0.0,
#    'sublayers': [{'id': 'SL1725264',
#      'sequence': 0,
#      'parameter1': '1.000000000000',
#      'parameter2': '1.000000000000',
#      'lambda': None,
#      'partId': 'WS9',
#      'status': 'NEW',
#      'delta': None,
#      'environmentalCost': 0.0,
#      'layered': False}]},
#   {'id': 'L1630674',
#    'sequence': 2,
#    'environmentalCost': None,
#    'rvalue': 0.0,
#    'sublayers': [{'id': 'SL1725265',
#      'sequence': 0,
#      'parameter1': '0.130000000000',
#      'parameter2': '1.000000000000',
#      'lambda': None,
#      'partId': 'WS4',
#      'status': 'NEW',
#      'delta': None,
#      'environmentalCost': 0.558109,
#      'layered': False}]},
#   {'id': 'L1630675',
#    'sequence': 3,
#    'environmentalCost': None,
#    'rvalue': 0.0,
#    'sublayers': [{'id': 'SL1725266',
#      'sequence': 0,
#      'parameter1': '0.000200000000',
#      'parameter2': '1.000000000000',
#      'lambda': None,
#      'partId': 'WS10',
#      'status': 'NEW',
#      'delta': None,
#      'environmentalCost': 0.0710354,
#      'layered': False}]},
#   {'id': 'L1630676',
#    'sequence': 4,
#    'environmentalCost': None,
#    'rvalue': 0.0882353,
#    'sublayers': [{'id': 'SL1725267',
#      'sequence': 0,
#      'parameter1': '0.150000000000',
#      'parameter2': '1.000000000000',
#      'lambda': '1.700000000000',
#      'partId': 'WS1720',
#      'status': 'NEW',
#      'delta': None,
#      'environmentalCost': 6.72328,
#      'layered': False}]},
#   {'id': 'L1630677',
#    'sequence': 5,
#    'environmentalCost': None,
#    'rvalue': 4.64286,
#    'sublayers': [{'id': 'SL1725268',
#      'sequence': 0,
#      'parameter1': '0.130000000000',
#      'parameter2': '1.000000000000',
#      'lambda': '0.028000000000',
#      'partId': 'WS31',
#      'status': 'NEW',
#      'delta': None,
#      'environmentalCost': 5.74971,
#      'layered': False}]},
#   {'id': 'L1630678',
#    'sequence': 6,
#    'environmentalCost': None,
#    'rvalue': 0.0,
#    'sublayers': [{'id': 'SL1725269',
#      'sequence': 0,
#      'parameter1': '0.002000000000',
#      'parameter2': '1.000000000000',
#      'lambda': None,
#      'partId': 'WS26',
#      'status': 'NEW',
#      'delta': None,
#      'environmentalCost': 0.226622,
#      'layered': False}]},
#   {'id': 'L1630679',
#    'sequence': 7,
#    'environmentalCost': None,
#    'rvalue': 0.037037,
#    'sublayers': [{'id': 'SL1725270',
#      'sequence': 0,
#      'parameter1': '0.050000000000',
#      'parameter2': '1.000000000000',
#      'lambda': '1.350000000000',
#      'partId': 'WS22',
#      'status': 'NEW',
#      'delta': None,
#      'environmentalCost': 0.685875,
#      'layered': False}]},
#   {'id': 'L1630680',
#    'sequence': 8,
#    'environmentalCost': None,
#    'rvalue': 0.0123457,
#    'sublayers': [{'id': 'SL1725271',
#      'sequence': 0,
#      'parameter1': '0.010000000000',
#      'parameter2': '1.000000000000',
#      'lambda': '0.810000000000',
#      'partId': 'WS12',
#      'status': 'NEW',
#      'delta': None,
#      'environmentalCost': 12.4403,
#      'layered': False}]}],
#  'results': {'lifeCyclePhaseIds': [],
#   'impactIndicatorIds': [],
#   'results': [],
#   'monetizedResults': [],
#   'timestamp': None,
#   'signature': 'ZOiDY3f6vIei/4MPHu7whA3yu3y3BDP+J8T/eZb4Tjk='}}

# %%
functional_units = [t["dimensionalParameterId"] for t in element_types]
print(len(element_types))
print(len(functional_units))
for fu in set(functional_units):
    count = len([x for x in functional_units if x == fu])
    print(fu, count)

print(functional_units)
# [t for t in element_types if t["id"] == "ET305092"]
# Out:
# 414
# 414
# 84 15
# 79 344
# 80 55
# ['79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '80', '80', '80', '80', '80', '80', '80', '80', '80', '80', '80', '80', '80', '80', '80', '80', '80', '80', '80', '80', '80', '80', '80', '80', '80', '80', '80', '80', '80', '80', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '84', '84', '84', '80', '80', '80', '84', '84', '84', '80', '80', '80', '80', '80', '80', '80', '80', '80', '80', '80', '80', '80', '80', '80', '80', '80', '80', '80', '80', '80', '80', '79', '79', '79', '84', '84', '84', '84', '84', '84', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '84', '84', '84']

# %%
element_types_dict = defaultdict(list)
for e in element_types:
    r = get_reference(e["reference"])
    element_types_dict[r].append(e)

# %%
ifc_paths = [
    "data/Blok O/3D/IFC/BLKO-KAAN-ZZ-ZZ-M-A-0001-Architecture_new.ifc",
    "data/StrijpS/3D/IFC/STRIJP-KAAN-ZZ-ZZ-M-A-0101.ifc",
    "data/Lumiere/3D/IFC/Lumiere_KAAN_Bouwkundig.ifc",
    "data/Overhoeks/3D/IFC/OHG_B_BWK_KAA_Bouwkundig.ifc",
    "data/SPOT/3D/IFC/SPOT_X_KAAN_BK_B_A1_R20.ifc",
    "data/SPOT/3D/IFC/SPOT_X_KAAN_BK_B_A2_R20.ifc",
    "data/SPOT/3D/IFC/SPOT_X_KAAN_BK_B_B2_R20.ifc",
    "data/SPOT/3D/IFC/SPOT_X_KAAN_BK_B_K_R20.ifc",
    "data/Zalmhaven/3D/IFC/ZHA-B-BWK-B-MR-R18.ifc",
]

# %%
product_references = {}
for ifc_path in ifc_paths:
    model = ifcopenshell.open(ifc_path)
    for product in model.by_type("IfcProduct"):
        if product.Representation is None or product.is_a("IfcSpace"):
            continue
        if product.Name is not None:
            name = get_name(product)
            references = ifcopenshell.util.classification.get_references(product)
            if len(references) > 0:
                reference = list(references)[0][1]
                reference = reference.split(".")
                if reference[0] in element_types_dict:
                    product_references[name] = reference

# %%
len(product_references)
# Out:
# 797

# %%
product_references
# Out:
# {'Basic Wall:K_20_WA_GF pigmented wall placeholder': ['22', '00'],
#  'Basic Wall:K_22_WA_Concrete in-situ': ['22', '21'],
#  'Floor:K_23_FL_Grass placeholder': ['23', '00'],
#  'Floor:K_23_FL_Parking': ['23', '00'],
#  'Basic Wall:K_21_WA_Housing facade placeholder': ['21', '00'],
#  'Basic Wall:K_20_WA_Generic': ['22', '00'],
#  'Basic Wall:K_21_WA_Concrete precast': ['21', '21'],
#  'Floor:K_23_FL_Concrete in-situ': ['23', '21'],
#  'Basic Wall:K_21_WA_Housing facade insulation and alu finish': ['21', '00'],
#  'Floor:K_23_FL_Balcony_Lower levels': ['23', '00'],
#  'Basic Wall:K_21_WA_Housing facade insulation and stone finish': ['21', '00'],
#  'Floor:K_23_FL_Balcony_Generic': ['23', '00'],
#  'Basic Wall:K_20_WA_Balustrade_pigmented': ['22', '00'],
#  'K_28_SCO_TLB_Generic': ['28', '11'],
#  'K_30_WIN_WB_Generic_2 panes_vertical:WI.xxxx_2000x2450mm_housing': ['31',
#   '21'],
#  'K_32_DO_WB': ['32', '31'],
#  'Basic Wall:K_20_WA_Ceramic_300mm': ['22', '00'],
#  'K_30_WIN_WB_Generic_1 pane_placeholder:WI.xxxx_1000x2450mm': ['31', '21'],
#  'K_30_WIN_WB_Generic_2 panes_vertical:WI.xxxx_1600x2450mm_housing': ['31',
#   '21'],
#  'K_30_WIN_WB_Generic_2 panes_vertical:WI.xxxx_1600x2550mm_housing': ['31',
#   '21'],
#  'Floor:K_23_FL_Balcony_Upper levels': ['23', '00'],
#  'K_32_DO_WB_Generic single:Standard': ['32', '31'],
#  'K_30_WIN_WB_Generic_1 pane_placeholder:WI.xxxx_1800x2400mm': ['31', '21'],
#  'Basic Wall:K_21_WA_insulation': ['21', '00'],
#  'K_30_WIN_WB_Generic_2 panes_vertical:WI.xxxx_2000x2450mm_housing_plinth': ['31',
#   '21'],
#  'K_30_WIN_WB_Generic_2 panes_vertical:WI.xxxx_2000x2250mm_housing_plinth': ['31',
#   '21'],
#  'K_28_SCO_TLB_column': ['28', '11'],
#  'Floor:K_23_FL_Concrete': ['23', '10'],
#  'K_28_SF_LIB_Beam_Rectangular:Concrete': ['16', '12'],
#  'Floor:K_23_FL_Wood CLT': ['23', '00'],
#  'K_28_SF_LIB_Beam_Rectangular:28_SF_LIB_Beam': ['28', '11'],
#  'Floor:K_23_FL_Insulation': ['23', '00'],
#  'Basic Wall:K_22_WA_Concrete': ['22', '21'],
#  'Basic Wall:K_21_WA_Aluminium framework': ['21', '10'],
#  'Basic Wall:K_21_WA_Wood': ['21', '10'],
#  'Floor:K_27_FL_Soil+grass': ['27', '12'],
#  'Basic Wall:K_21_WA_Wood+Insulation': ['21', '10'],
#  'Basic Wall:K_22_WA_Metalstud_dubbel_2.75-75.2': ['22', '13'],
#  'Basic Wall:K_22_WA_Metalstud_2.75-75.2': ['22', '12'],
#  'Basic Wall:K_22_WA_Metalstud_2.105.2': ['22', '13'],
#  'Basic Wall:K_22_WA_Metalstud_2.50.2': ['22', '13'],
#  'K_32_DO_WB_Single:DO.xxxx': ['32', '31'],
#  'Basic Wall:K_22_WA_Brickwork': ['22', '11'],
#  'Basic Wall:K_22_WA_Metalstud_2.75': ['22', '13'],
#  'Floor:K_23_FL_Concrete+screed': ['23', '10'],
#  'Basic Wall:K_22_WA_Metalstud_2.80': ['22', '13'],
#  'K_31_WIN_WB_Aluminum_Regular_fixed:WI.xxxx': ['31', '21'],
#  'K_31_WIN_WB_Tilt_openable:WI.xxxx': ['31', '24'],
#  'K_31_WIN_WB_Regular_openable:WI.xxxx_swing': ['31', '21'],
#  'K_32_DO_WB_Single door:DO.xxxx': ['32', '31'],
#  'K_31_WIN_WB_Aluminum_Sliding door_2 pane_same side:WI.xxxx': ['31', '23'],
#  'Basic Wall:K_22_WA_Metalstud': ['22', '11'],
#  'Basic Wall:K_22_WA_CLT': ['22', '11'],
#  'Basic Wall:K_21_WA_HSB': ['21', '13'],
#  'Basic Wall:K_22_WA_Metalstud_schacht_45.1': ['22', '13'],
#  'Basic Wall:K_22_WA_Metalstud_2-2': ['22', '13'],
#  'Floor:K_23_FL': ['23', '20'],
#  'Basic Wall:K_22_WA_Metalstud_schacht_75.2': ['22', '13'],
#  'Basic Wall:K_21_WA_Wood CLT': ['21', '10'],
#  'K_32_DO_WB_Single:DO.xxxx_wood': ['32', '31'],
#  'Basic Wall:K_21_WA_Wood finish': ['21', '10'],
#  'Floor:K_23_FL_Wood': ['23', '10'],
#  'Basic Wall:K_22_WA_Concrete+Insulation': ['22', '21'],
#  'K_32_DO_WB_Double:DO.xxxx': ['32', '31'],
#  'Floor:K_23.10_FL_Plasterboard': ['23', '10'],
#  'Basic Wall:K_22_WA_Plasterboard_2': ['22', '13'],
#  'Floor:K_23_FL_Concrete sidewalk': ['23', '10'],
#  'Floor:K_23_FL_Generic': ['23', '00'],
#  'Floor:K_23_FL_Stone sidewalk': ['23', '00'],
#  'K_32_WIN_WB_Panel fixed:WI.xxxx': ['32', '21'],
#  'K_32_DO_WB_Sliding door panel:DO.xxxx': ['32', '32'],
#  'Basic Wall:K_22_WA_Insulation': ['22', '13'],
#  'Basic Wall:K_22_WA_Metalstud_WKO_2.50.2': ['22', '13'],
#  'Basic Wall:K_22_WA_Metalstud_ECT_2.50.2': ['22', '13'],
#  'Basic Wall:K_22_WA_Metalstud_MK_1.82': ['22', '13'],
#  'Basic Wall:K_22_WA_Metalstud_ECT_1.82': ['22', '13'],
#  'Floor:K_23_FL_Screed+Insulation': ['23', '10'],
#  'K_32_DO_WB_Single door_wood:DO.xxxx': ['32', '31'],
#  'Basic Wall:K_22_WA_Aluminium cladding': ['22', '13'],
#  'Basic Roof:K_27_RO': ['27', '11'],
#  'Floor:K_23_FL_Concrete prefab': ['23', '10'],
#  'Basic Wall:K_22_WA_Metalstud_1.75.1': ['22', '13'],
#  'Basic Wall:K_22_WA_Metalstud_2.40': ['22', '12'],
#  'Floor:K_23_FL_Concrete sidewalk white': ['23', '10'],
#  'Floor:K_23_FL_Screed+insulation': ['23', '10'],
#  'Basic Wall:K_21_Generiek': ['21', '14'],
#  'K_21_Elementgevel_paneel_standaard:Glas': ['21', '14'],
#  'K_21_Elementgevel_paneel_buitenhoek:Glas': ['21', '14'],
#  'K_21_Elementgevel_paneel_standaard:Aluminium': ['21', '14'],
#  'K_21_Elementgevel_paneel_buitenhoek:Aluminium': ['21', '14'],
#  'Basic Wall:K_22_Kalkzandsteen': ['22', '11'],
#  'K_32_Deur_enkel:DO.xxxx_1040x2370(900x2300)mm': ['32', '31'],
#  'Basic Wall:K_21_Roostergevel': ['21', '10'],
#  'Basic Wall:K_21_HSB': ['21', '12'],
#  'Floor:K_27_Luifel_generiek': ['27', '13'],
#  'Basic Wall:K_22_Metalstud_2.100.2': ['22', '13'],
#  'K_31_WIN_WB_Raam_laagbouw_vast:WI.xxxx': ['31', '21'],
#  'Basic Wall:K_22_Generiek': ['22', '00'],
#  'Basic Wall:K_22_Beton_ihwg': ['22', '21'],
#  'K_28_Kolom_rechthoekig:Beton_ihwg': ['28', '11'],
#  'Floor:K_23_Beton_ihwg': ['23', '21'],
#  'Basic Wall:K_22_Metalstud_schacht_75.2': ['22', '13'],
#  'Basic Wall:K_22_Metalstud_dubbel_2.45-45.2': ['22', '13'],
#  'Basic Wall:K_22_Metalstud_schacht_50.2': ['22', '13'],
#  'Basic Wall:K_22_Metalstud_2.50.2': ['22', '13'],
#  'K_28_Ligger_rechthoekig:Beton_ihwg': ['28', '11'],
#  'Floor:K_23_Kanaalplaatvloer': ['23', '21'],
#  'Basic Wall:K_22_Glas': ['22', '10'],
#  'Foundation Slab:K_13_Beton_ihwg': ['13', '22'],
#  'K_28_Kolom_rond:Staal': ['28', '11'],
#  'Basic Wall:K_22_Metalstud_2.75.2': ['22', '13'],
#  'Basic Wall:K_22_Beton_prefab': ['22', '21'],
#  'K_28_Kolom_rechthoekig:Staal': ['28', '11'],
#  'K_28_Kolom_rond:Beton': ['28', '11'],
#  'Basic Wall:K_22_Metalstud_dubbel_2.75-75.2': ['22', '13'],
#  'K_32_Deur_profielstaal_enkel:DO.xxxx': ['32', '31'],
#  'Basic Wall:K_21_Glas': ['21', '10'],
#  'Floor:K_23_Beton_prefab': ['23', '00'],
#  'K_32_Deur_enkel:DO.xxxx_1040x2370(900x2300)mm_250mm': ['32', '31'],
#  'K_32_Deur_enkel:DO.xxxx_schacht_1040x2370(900x2300)mm': ['32', '31'],
#  'Basic Wall:K_22_Metalstud_schacht_45.1': ['22', '13'],
#  'Basic Wall:K_22_Cellenbeton': ['22', '11'],
#  'Basic Wall:K_22_Metalstud_1.45.1': ['22', '13'],
#  'K_32_Deur_enkel:DO.xxxx_990x2370(850x2300)mm': ['32', '31'],
#  'K_00_Installatievoorziening:K_57_Mechanische ventilatie': ['57', '00'],
#  'K_00_Installatievoorziening:K_56_CV': ['56', '00'],
#  'K_32_Deur_enkel:DO.xxxx_meterkast_840x2370(700x2300)mm': ['32', '31'],
#  'Basic Wall:K_22_Metalstud_voorzet_45.2': ['22', '13'],
#  'Basic Wall:K_22_Metalstud_voorzet_75.2': ['22', '13'],
#  'K_32_Deur_profielstaal_dubbel:DO.xxx': ['32', '31'],
#  'K_32_Deur_enkel:DO.xxxx_schacht_840x2370(700x2300)mm': ['32', '31'],
#  'Basic Wall:K_22_Metalstud_schacht_45.2': ['22', '13'],
#  'Floor:K_23_Glas': ['23', '10'],
#  'K_32_Deur_dubbel:DO.xxxx_1940x2370(1800x2300)mm': ['32', '31'],
#  'Floor:K_23_Generiek': ['23', '21'],
#  'K_28_Ligger_rechthoekig:Staal': ['28', '11'],
#  'K_32_Deur_dubbel:DO.xxxx_1650x2200(1510x2130)mm': ['32', '31'],
#  'K_32_Deur_dubbel:DO.xxxx_schacht_1940x2370(1800x2300)mm': ['32', '31'],
#  'Basic Wall:K_22_Metalstud_schacht_100.2': ['22', '13'],
#  'K_32_Deur_enkel:DO.xxxx_1050x2600(910x2530)mm_250mm': ['32', '31'],
#  'K_32_Deur_enkel:DO.xxxx_1300x2480(1160x2410)mm': ['32', '31'],
#  'K_32_Deur_dubbel:DO.xxxx_1540x2370(1400x2300)mm': ['32', '31'],
#  'K_32_Deur_dubbel:DO.xxxx_1650x2200(1210x2130)mm': ['32', '31'],
#  'Basic Wall:NLRS_22.10_GF 215 HT / 2.75.A': ['22', '10'],
#  'Basic Wall:NLRS_22.10_GIBO Standaard 70': ['22', '10'],
#  'Basic Wall:NLRS_22.10_GF 250 HT / 2.100x100.AA': ['22', '10'],
#  'Basic Wall:NLRS_22.10_GF 255 HT / 2.75x75.AA': ['22', '10'],
#  'Basic Wall:NLRS_21.10': ['21', '10'],
#  'Basic Wall:NLRS_21.10_Sandwich betonelement 300': ['21', '10'],
#  'Floor:NLRS_23.12_balkonvloer': ['23', '12'],
#  'Basic Wall:NLRS_22.10_GF 205 HT / 2.75x75.AA': ['22', '10'],
#  'NLRS_31.24_raam te openen (half) met zijlicht _gen:NLRS_31.24_raam te openen (half) met zijlicht_2250mm': ['31',
#   '24'],
#  'NLRS_31.24_raam te openen (half) met zijlicht _gen:NLRS_31.24_raam te openen (half) met zijlicht_1687mm': ['31',
#   '24'],
#  'NLRS_31.24_raam te openen (half) met zijlicht _gen:NLRS_31.24_raam te openen (half) met zijlicht_2155mm': ['31',
#   '24'],
#  'NLRS_31.24_raam vast_gen:NLRS_31.24_raam vast_Hoogte 2880_1125mm': ['31',
#   '24'],
#  'NLRS_31.24_raam te openen_gen:NLRS_31.24_raam te openen_1125mm': ['31',
#   '24'],
#  'NLRS_31.24_raam te openen (half) met zijlicht _gen:NLRS_31.24_raam te openen (half) met zijlicht_2152mm': ['31',
#   '24'],
#  'NLRS_31.24_raam te openen (half) met zijlicht _gen:NLRS_31.24_raam te openen (half) met zijlicht_2802.5 mm': ['31',
#   '24'],
#  'NLRS_31.24_raam vast_gen:NLRS_31.24_raam vast_1125mm': ['31', '24'],
#  'NLRS_31.24_raam vast_gen:NLRS_31.24_raam vast_1081mm': ['31', '24'],
#  'NLRS_31.24_raam te openen (half) met zijlicht _gen:NLRS_31.24_raam te openen (half) met zijlicht_2250*2880mm': ['31',
#   '24'],
#  'NLRS_31.24_raam te openen_gen:NLRS_31.24_raam te openen_1125x2880mm': ['31',
#   '24'],
#  'NLRS_31.24_raam vast_gen:NLRS_31.24_raam vast_1687.5mm': ['31', '24'],
#  'NLRS_31.24_raam te openen (half) met zijlicht _gen:NLRS_31.24_raam te openen (half) met zijlicht': ['31',
#   '24'],
#  'NLRS_31.24_raam schuif_gen:NLRS_31.24_raam vast_3375mm': ['31', '24'],
#  'NLRS_31.24_raam te openen (half) met zijlicht _gen:NLRS_31.24_raam te openen (half) met zijlicht hoogte 2880_1687mm': ['31',
#   '24'],
#  'NLRS_31.24_begane grond_raam te openen': ['31', '24'],
#  'NLRS_31.24_begane grond_raam te openen enkel zijlicht': ['31', '24'],
#  'NLRS_31.24_raam te openen (half) met zijlicht _gen:NLRS_31.24_raam te openen (half) met zijlicht_1728mm': ['31',
#   '24'],
#  'NLRS_32.31_DO_WB_kozijn Daloc S43_GEN:Daloc_S43_990x2370': ['32', '31'],
#  'Basic Wall:NLRS_22.10_GIBO Zwaar 70': ['22', '10'],
#  'NLRS_32.31_DO_profielstaalkozijn muuromvattend met enkele deur:2324x850_R': ['32',
#   '31'],
#  'NLRS_31.24_Hoek raam:NLRS_31.24_Hoek raam_BG': ['31', '24'],
#  'Basic Wall:NLRS_22.10_GIBO Hydro 70': ['22', '10'],
#  'NLRS_32.31_DO_profielstaalkozijn muuromvattend met enkele deur:2324x850_L': ['32',
#   '31'],
#  'Basic Wall:NLRS_22.10_GIBO Standaard 100': ['22', '10'],
#  'NLRS_32.31_DO_profielstaalkozijn muuromvattend met enkele deur - hoog plafond:2840x850_L': ['32',
#   '31'],
#  'Basic Wall:NLRS_22.10_MS 125 / 2.100.2.A': ['22', '10'],
#  'NLRS_32.31_DO_profielstaalkozijn muuromvattend met enkele deur - hoog plafond:2840x850_R': ['32',
#   '31'],
#  'Basic Wall:NLRS_22.10_GIBO Hydro 100': ['22', '10'],
#  'Basic Wall:NLRS_22.10_isolatie isokorf/steenwol': ['22', '10'],
#  'Basic Wall:NLRS_22.10_isolatie 110mm': ['22', '10'],
#  'Basic Wall:NLRS_22.11_Kalkzandsteen 100mm': ['22', '11'],
#  'Basic Wall:NLRS_22.10_MS 70': ['22', '10'],
#  'NLRS_32.31_DO_profielstaalkozijn muuromvattend met enkele deur:2324x730_R': ['32',
#   '31'],
#  'NLRS_31.24_begane grond_raam': ['31', '24'],
#  'NLRS_32.31_DO_profielstaalkozijn muuromvattend met dubbele deur:2324x1510': ['32',
#   '31'],
#  'NLRS_31.24_Hoek raam brandwerend:NLRS_31.24_Hoek raam_BG': ['31', '24'],
#  'Basic Wall:NLRS_22.10_GF 100 / 2.50.2.A': ['22', '10'],
#  'NLRS_32.31_DO_WB_kozijn Daloc S43_GEN:Daloc_S43_990x2370_B30': ['32', '31'],
#  'Basic Wall:NLRS_22.10_GF 150 / 2.100.2.A': ['22', '10'],
#  'Basic Wall:NLRS_22.10_MS 100 / 2.100.A': ['22', '10'],
#  'Basic Wall:NLRS_21.12': ['21', '12'],
#  'Basic Wall:NLRS_22.10_geisoleerd wandpaneel + houtvezelplaat 140mm': ['22',
#   '10'],
#  'Basic Wall:NLRS_22.11_kalkzandsteen 150': ['22', '11'],
#  'Basic Wall:NLRS_22.10_HSB 200mm': ['22', '10'],
#  'Basic Wall:NLRS_22.11_Kalkzandsteen 67 vellingblokken': ['22', '11'],
#  'NLRS_32.31_DO_houtenkozijn muuromvattend met enkele deur:114x67_2305x900_L': ['32',
#   '31'],
#  'NLRS_32.31_DO_houtenkozijn muuromvattend met enkele deur:114x67_2305x900_R': ['32',
#   '31'],
#  'NLRS_32.31_DO_houtenkozijn op stellat met enkele deur brandwerend:114x90_2374x1038_R': ['32',
#   '31'],
#  'NLRS_31.24_raam te openen (half) met zijlicht _gen:NLRS_31.24_raam te openen (half) met zijlicht_2813mm': ['31',
#   '24'],
#  'Basic Wall:NLRS_22.10_MS 75 / 2.50.A': ['22', '10'],
#  'NLRS_32.31_DO_houtenkozijn muuromvattend met enkele deur:114x67_1545x900_R': ['31',
#   '31'],
#  'Basic Wall:NLRS_22.11_Prefab beton 180mm': ['22', '11'],
#  'Basic Wall:NLRS_22.11_kalkzandsteen 300': ['22', '11'],
#  'Basic Wall:NLRS_22.11_Kalkzandsteen 100 vellingblokken': ['22', '11'],
#  'NLRS_32.31_DO_houtenkozijn muuromvattend met enkele deur:114x67_2105x900_R': ['32',
#   '31'],
#  'NLRS_31.24_Hoek raam:NLRS_31.24_Hoek raam': ['31', '24'],
#  'NLRS_31.24_raam vast_gen:NLRS_31.24_raam vast_2105mm': ['31', '24'],
#  'NLRS_31.31_begane grond enkele deur_gen:NLRS_31.31_enkele deur_1105mm': ['31',
#   '31'],
#  'Basic Wall:NLRS_22.10_MS 114': ['22', '10'],
#  'NLRS_31.31_begane grond enkele deur met bovenlicht_fiets G1_gen:NLRS_31.31_enkele deur met bovenlicht_... mm': ['31',
#   '31'],
#  'NLRS_31.31_begane grond enkele deur met bovenlicht_fiets_gen 2:NLRS_31.31_enkele deur met zijlicht_... mm': ['31',
#   '31'],
#  'NLRS_31.31_begane grond enkele deur met zijlicht_entree_gen 2:NLRS_31.31_enkele deur met zijlicht_... mm': ['31',
#   '31'],
#  'NLRS_31.24_raam te openen (half) met zijlicht _gen:NLRS_31.24_raam te openen (half) met zijlicht_3016mm': ['31',
#   '24'],
#  'NLRS_31.24_raam te openen (half) met zijlicht _gen:NLRS_31.24_raam te openen (half) met zijlicht_2258mm': ['31',
#   '24'],
#  'NLRS_31.24_raam vast_gen:NLRS_31.24_raam vast_2240mm': ['31', '24'],
#  'NLRS_31.24_raam te openen (half) met zijlicht _gen:NLRS_31.24_raam te openen (half) met zijlicht_1687x2575mm': ['31',
#   '24'],
#  'NLRS_31.24_raam vast_gen:NLRS_31.24_raam vast_1952mm': ['31', '24'],
#  'NLRS_31.24_raam vast_gen:NLRS_31.24_raam vast_2078mm': ['31', '24'],
#  'NLRS_31.24_raam vast_gen:NLRS_31.24_raam vast_2244mm': ['31', '24'],
#  'NLRS_31.24_raam te openen (half) met zijlicht _gen:NLRS_31.24_raam te openen (half) met zijlicht_2040mm': ['31',
#   '24'],
#  'NLRS_31.24_raam vast_gen:NLRS_31.24_raam vast_2172mm x 2740mm': ['31', '24'],
#  'NLRS_31.24_raam te openen (half) met zijlicht _gen:NLRS_31.24_raam te openen (half) met zijlicht_1687mm x 2740mm': ['31',
#   '24'],
#  'NLRS_31.24_raam te openen_gen:NLRS_31.24_raam te openen_1125mm x 2745mm': ['31',
#   '24'],
#  'NLRS_31.24_raam te openen (half) met zijlicht _gen:NLRS_31.24_raam te openen (half) met zijlicht_2125mm x 2740mm': ['31',
#   '24'],
#  'NLRS_31.24_raam te openen (half) met zijlicht _gen:NLRS_31.24_raam te openen (half) met zijlicht_2414mm x 2740mm': ['31',
#   '24'],
#  'NLRS_31.24_raam te openen_gen:NLRS_31.24_raam te openen_1125mm x 2740mm': ['31',
#   '24'],
#  'NLRS_31.24_raam te openen (half) met zijlicht _gen:NLRS_31.24_raam te openen (half) met zijlicht_2832.5 mm x 2740mm': ['31',
#   '24'],
#  'NLRS_31.24_raam te openen (half) met zijlicht _gen:NLRS_31.24_raam te openen (half) met zijlicht_2152mm x 2740mm': ['31',
#   '24'],
#  'NLRS_31.24_raam te openen (half) met zijlicht _gen:NLRS_31.24_raam te openen (half) met zijlicht_2250mm x 2745mm': ['31',
#   '24'],
#  'NLRS_31.24_raam vast_gen:NLRS_31.24_raam vast_1081mm x 2740mm': ['31', '24'],
#  'NLRS_32.31_DO': ['32', '31'],
#  'NLRS_31.10': ['31', '10'],
#  'NLRS_31.24_raam te openen (half) met zijlicht _gen:NLRS_31.24_raam te openen (half) met zijlicht_2792.5 mm x 2740mm': ['31',
#   '24'],
#  'NLRS_31.24_raam te openen (half) met zijlicht _gen:NLRS_31.24_raam te openen (half) met zijlicht_2792.5 mm': ['31',
#   '24'],
#  'NLRS_31.24_raam te openen (half) met zijlicht _gen:NLRS_31.24_raam te openen (half) met zijlicht_2290mm': ['31',
#   '24'],
#  'NLRS_32.31_DO_houtenkozijn muuromvattend met enkele deur:114x67_2105x900_L': ['32',
#   '31'],
#  'Basic Wall:NLRS_22.10_GLASS_ 30': ['22', '10'],
#  'Basic Wall:NLRS_22.10_GF 280 / 2.75-75.2.AAA': ['22', '10'],
#  'NLRS_31.24_raam te openen (half) met zijlicht _gen:NLRS_31.24_raam te openen (half) met zijlicht_3365 mm': ['31',
#   '24'],
#  'NLRS_31.24_raam te openen (half) met zijlicht _gen:NLRS_31.24_raam te openen (half) met zijlicht_2357*2880mm': ['31',
#   '24'],
#  'NLRS_31.24_raam vast_gen:NLRS_31.24_raam vast_Hoogte 2880 mm': ['31', '24'],
#  'Basic Wall:NLRS_22.10_GF 215 HT / 2.75.A + 55 lucht': ['22', '10'],
#  'Basic Wall:NLRS_22.10_GF 280 HT / 2.100x100.AA': ['22', '10'],
#  'NLRS_31.24_raam te openen (half) met zijlicht _gen:NLRS_31.24_raam te openen (half) met zijlicht_2125mm': ['31',
#   '24'],
#  'NLRS_31.24_raam vast_gen:NLRS_31.24_raam vast_1138mm': ['31', '24'],
#  'NLRS_31.24_raam vast_gen:NLRS_31.24_raam vast_2254mm': ['31', '24'],
#  'NLRS_31.24_raam vast_gen:NLRS_31.24_raam vast_1687.5mm x 2740mm': ['31',
#   '24'],
#  'NLRS_31.24_raam vast_gen:NLRS_31.24_raam vast_576.5mm x 2740mm': ['31',
#   '24'],
#  'NLRS_31.24_raam vast_gen:NLRS_31.24_raam vast_1125mm x 2740mm': ['31', '24'],
#  'NLRS_31.24_raam te openen (half) met zijlicht _gen:NLRS_31.24_raam te openen (half) met zijlicht_2831x2880mm': ['31',
#   '24'],
#  'NLRS_32.31_DO_profielstaalkozijn muuromvattend met enkele deur - hoog plafond:2840x730_L': ['32',
#   '31'],
#  'NLRS_32.31_DO_profielstaalkozijn muuromvattend met enkele deur - hoog plafond:2840x730_R': ['32',
#   '31'],
#  'NLRS_32.31_DO_profielstaalkozijn muuromvattend met enkele deur:2324x730_L': ['32',
#   '31'],
#  '00_GM': ['32', '30'],
#  'NLRS_31.24_raam te openen (half) met zijlicht _gen:NLRS_31.24_raam te openen (half) met zijlicht_2487mm': ['31',
#   '24'],
#  'NLRS_32.31_DO_profielstaalkozijn muuromvattend met dubbele deur:2324x1810': ['32',
#   '31'],
#  'NLRS_31.24_raam entree_met_natuursteen': ['31', '24'],
#  'NLRS_31.31_begane grond enkele deur met zijlicht_entree G2 Opt 2_gen:NLRS_31.31_enkele deur met zijlicht_... mm': ['31',
#   '31'],
#  'Basic Wall:NLRS_21.12_isolatie EPS': ['21', '12'],
#  'NLRS_32.24_raam houten kozijn_gen:2377x686': ['32', '24'],
#  'NLRS_32.31_DO_houtenkozijn met enkele deur:2377x1044': ['32', '31'],
#  'NLRS_32.24_raam houten kozijn_gen:2377x306': ['32', '24'],
#  'NLRS_32.24_raam houten kozijn_gen:2377x576': ['32', '24'],
#  'NLRS_32.24_raam houten kozijn_gen:2680x1194': ['32', '24'],
#  'NLRS_32.24_raam houten kozijn_gen:2680x1711': ['32', '24'],
#  'NLRS_32.31_DO_houtenkozijn met enkele deur en bovenlicht:2680x1001': ['32',
#   '31'],
#  'NLRS_32.24_raam houten kozijn_gen:943x1350': ['32', '24'],
#  'NLRS_32.24_raam houten kozijn_gen:943x1730': ['32', '24'],
#  'NLRS_32.24_raam houten kozijn_gen:943x1620': ['32', '24'],
#  'NLRS_32.24_raam houten kozijn_gen:2840x1194': ['32', '24'],
#  'NLRS_32.24_raam houten kozijn_gen:2840x1711': ['32', '24'],
#  'NLRS_32.31_DO_houtenkozijn met enkele deur en bovenlicht:2840x1001': ['32',
#   '30'],
#  'NLRS_32.24_raam houten kozijn_gen:2377x432': ['32', '24'],
#  'NLRS_32.24_raam houten kozijn_gen:2377x1470': ['32', '24'],
#  'NLRS_32.24_raam houten kozijn_gen:2377x736': ['32', '24'],
#  'NLRS_32.24_raam houten kozijn_gen:943x1470': ['32', '24'],
#  'NLRS_32.24_raam houten kozijn_gen:943x1770': ['32', '24'],
#  'NLRS_32.24_raam houten kozijn_gen:943x1467': ['32', '24'],
#  'NLRS_32.24_raam houten kozijn_gen:2377x476': ['32', '24'],
#  'NLRS_32.24_raam houten kozijn_gen:943x1510': ['32', '24'],
#  'NLRS_32.24_raam houten kozijn_gen:2377x486': ['32', '24'],
#  'NLRS_32.24_raam houten kozijn_gen:943x1520': ['32', '24'],
#  'NLRS_32.24_raam houten kozijn_gen:2377x426': ['32', '24'],
#  'NLRS_32.24_raam houten kozijn_gen:2680x1440': ['32', '24'],
#  'NLRS_32.24_raam houten kozijn_gen:2680x1470': ['32', '24'],
#  'NLRS_32.24_raam houten kozijn_gen:2680x439': ['32', '24'],
#  'NLRS_32.24_raam houten kozijn_gen:2680x1080': ['32', '24'],
#  'NLRS_32.24_raam houten kozijn_gen:2680x1326': ['32', '24'],
#  'NLRS_32.31_DO_houtenkozijn met enkele deur en bovenlicht:2680x1044': ['32',
#   '31'],
#  'NLRS_32.24_raam houten kozijn_gen:2680x282': ['32', '24'],
#  'NLRS_32.24_raam houten kozijn_gen:2680x1710': ['32', '24'],
#  'NLRS_32.24_raam houten kozijn_gen:2680x486': ['32', '24'],
#  'NLRS_32.31_DO_houtenkozijn met enkele deur en bovenlicht:2930x1044': ['32',
#   '31'],
#  'NLRS_32.31_DO_houtenkozijn met enkele deur en bovenlicht:2930x1001': ['32',
#   '31'],
#  'NLRS_32.24_raam houten kozijn_gen:2930x1630': ['32', '24'],
#  'NLRS_32.24_raam houten kozijn_gen:2930x600': ['32', '24'],
#  'NLRS_32.24_raam houten kozijn_gen:2930x1080': ['32', '24'],
#  'Basic Wall:NLRS_21.00': ['21', '00'],
#  'Floor:23.10_Prefab betonvloer': ['23', '10'],
#  'NLRS_32.24_raam houten kozijn_gen:2680x1200': ['32', '24'],
#  'NLRS_32.24_raam houten kozijn_gen:2377x425': ['32', '24'],
#  'NLRS_32.31_DO_profielstaalkozijn muuromvattend met enkele deur:2324x850_R_binnendeur': ['32',
#   '31'],
#  'NLRS_32.31_DO_profielstaalkozijn muuromvattend met dubbele deur:2324x1810_binnendeur': ['32',
#   '31'],
#  'NLRS_32.31_DO_houtenkozijn met enkele deur en dicht bovenlicht:2680x1001': ['32',
#   '31'],
#  'NLRS_32.24_raam houten kozijn_gen:2377x456': ['32', '24'],
#  'NLRS_32.24_raam houten kozijn_gen:833x1500': ['32', '24'],
#  '31.30_DO': ['31', '30'],
#  'NLRS_32.31_DO_kozijn met dubbele deur:1030x2365_berging deur_zelfsluitend': ['32',
#   '30'],
#  'NLRS_32.31_DO_houtenkozijn op stellat met enkele deur:114x67_2305x940_R': ['32',
#   '31'],
#  'NLRS_32.31_DO_houtenkozijn op stellat met enkele deur brandwerend:114x90_2374x1038_L': ['32',
#   '31'],
#  'Basic Wall:NLRS_22.11_Prefab beton aanrijdbeveiliging 300mm': ['22', '11'],
#  'NLRS_32.24_raam houten kozijn_gen:2377x826': ['32', '24'],
#  'NLRS_32.24_raam houten kozijn_gen:833x1870': ['32', '24'],
#  'NLRS_32.24_raam houten kozijn_gen:2377x726': ['32', '24'],
#  'NLRS_32.24_raam houten kozijn_gen:833x1770': ['32', '24'],
#  'NLRS_32.31_DO_houtenkozijn op stellat met enkele deur brandwerend:114x90_1479x838_R': ['31',
#   '31'],
#  '21.13_COL': ['21', '13'],
#  '21.13_COL_HSB kolom': ['21', '13'],
#  'NLRS_32.21_entree raam B60': ['32', '21'],
#  'Basic Wall:NLRS_22.10_ isolatie sandwich paneel aluminium 60mm': ['22',
#   '10'],
#  '56_PIA_WPB': ['56', '11'],
#  '00_LF_outer light:57': ['57', '52'],
#  'NLRS_31.24_raam te openen (half) met zijlicht _gen:NLRS_31.24_raam te openen (half) met zijlicht_3765 mm': ['31',
#   '24'],
#  'Basic Wall:NLRS_22.10_Multiplex 30mm': ['22', '10'],
#  'NLRS_32.31_DO_kozijn met dubbele deur kelder:1200x2300': ['32', '30'],
#  'Basic Wall:NLRS_22.10_GF 25 / 2.A': ['22', '10'],
#  'NLRS_32.31_DO_profielstaalkozijn muuromvattend met enkele deur:2324x700_R': ['32',
#   '31'],
#  'Basic Wall:22_WA_MS 100/2.50.2.A': ['22', '13'],
#  'Basic Wall:22_WA_MV 120/3.75.A': ['22', '13'],
#  'Basic Wall:22_WA_gibo zwaar': ['22', '11'],
#  'Basic Wall:22_WA_MS 205/2.75.75.2.AA': ['22', '13'],
#  'Basic Wall:22_WA_gibo': ['22', '11'],
#  'Basic Wall:22_WA_MS 155/2.50.50.2.AA': ['22', '13'],
#  '32_DO_WB_houten woningvoordeur_metalstud:Door_1064x2410': ['32', '31'],
#  '32_DO_WB_binnendeur staal:DO_1000x2780': ['32', '31'],
#  'Basic Wall:22_WA_MV 80/2.50.A': ['22', '13'],
#  '32_DO_WB_Houten deur_beton:Door_1018x2392_B60 SA': ['32', '31'],
#  '32_DO_WB_kozijn staal binnen:Door_1000x2400': ['32', '31'],
#  '32_DO_WB_houten woningvoordeur_beton:Door_1064x2410': ['32', '31'],
#  '32_DO_WB_binnendeur staal:DO_850x2780': ['32', '31'],
#  'Basic Wall:22_WA_MS 167.5/3.50.50.2.AA': ['22', '13'],
#  '32_DO_WB_Houten deur_metalstud:Door_968x2392_B60': ['32', '31'],
#  '32_DO_WB_binnendeur staal:DO_1000x2630': ['32', '31'],
#  '32_DO_WB_binnendeur staal:DO_850x2630': ['32', '31'],
#  '32_DO_WB_binnendeur staal:DO_800x2630': ['32', '31'],
#  '32_DO_WB_binnendeur staal:DO_800x2780': ['32', '31'],
#  'Basic Wall:41_WA_sandwichpaneel': ['21', '13'],
#  'Basic Wall:21_WA_HSB': ['21', '13'],
#  '28_SCO_kolom rechthoekig ihwg': ['28', '11'],
#  'Basic Wall:22_WA_MS 200/3.125.3.A': ['22', '13'],
#  'Basic Wall:22_WA_MS 200/2.150.2.A': ['22', '13'],
#  'Basic Wall:22_WA_MV 100/2.75.A': ['22', '13'],
#  '32_DO_WB_Houten deur_metalstud:Door_1018x2392': ['32', '31'],
#  '32_DO_WB_Houten deur_beton:Door_1018x2392': ['32', '31'],
#  'Basic Wall:22_WA_MS 150/2.100.2.A': ['22', '13'],
#  '32_DO_WB_Houten deur_metalstud:Door_1018x2392_B30': ['32', '31'],
#  'Basic Wall:22_WA_kalkzandsteen': ['22', '11'],
#  'Basic Wall:22_WA_MS 125/2.75.2.A': ['22', '13'],
#  'Basic Wall:22_WA_MS 125/3.50.3.A': ['22', '13'],
#  'Basic Wall:22_WA_MS 70/1.45.1.A': ['22', '13'],
#  '32_DO_WB_kozijn staal binnen:Door_970x2400': ['32', '31'],
#  'Basic Wall:22_WA_MS 175/3.100.3.A': ['22', '13'],
#  'Basic Wall:22_WA_MV 75/2.50': ['22', '13'],
#  'NLRS_28.10_SBS_balk rechthoekig ihwg_GEN:500x800': ['28', '11'],
#  'Floor:00_FL_dakenpaket': ['27', '21'],
#  'Basic Wall:22_WA_MV 150/2.125': ['22', '13'],
#  '32_DO_WB_Houten deur_beton:Door_1018x2392_B00': ['32', '31'],
#  'Floor:23_FL_isolatie': ['23', '10'],
#  'System Panel:37_CWP_glas': ['31', '40'],
#  'Rectangular Mullion:37.20 CWM Schuco 165x60': ['31', '40'],
#  'Rectangular Mullion:37.20 CWM Schuco 260x60': ['31', '40'],
#  'Rectangular Mullion:37.20 CWM Schuco 285x60': ['21', '14'],
#  '32_DO_WB_kozijn_dubbele deur links_curtain wall_gevel_Schuco:Kozijn curtain wall_glas_GEN': ['31',
#   '40'],
#  '32_DO_WB_kozijn_dubbele deur rechts_curtain wall_gevel_Schuco:Kozijn curtain wall_glas_GEN': ['31',
#   '40'],
#  'Rectangular Mullion:37.20 CWM Schuco 310x60': ['21', '14'],
#  '32_DO_WB_kozijn curtain wall_gevel_Schuco:Kozijn curtain wall_glas_GEN': ['21',
#   '14'],
#  'Rectangular Mullion:37.20 CWM Schuco 265x60': ['31', '40'],
#  'Rectangular Mullion:37_CWM': ['21', '14'],
#  '32_DO_WB_Houten deur_metalstud:Door_1018x2392_B00': ['32', '31'],
#  '31_WIN_WB_raam:A1_L04-13_O/W': ['32', '20'],
#  '31_WIN_WB': ['32', '21'],
#  'NLRS_00.00_GM': ['28', '11'],
#  '31_WIN_WB_aluminium kozijn kantoren_5 panelen:Ae_043': ['31', '21'],
#  '31_WIN_WB_aluminium kozijn kantoren_5 panelen:Ae_044': ['31', '21'],
#  '31_WIN_WB_aluminium kozijn kantoren_5 panelen:Ae_053': ['31', '21'],
#  '31_WIN_WB_aluminium kozijn kantoren_5 panelen:Ae_054': ['31', '21'],
#  '31_WIN_WB_aluminium kozijn kantoren_4 panelen:Ae.050_aluminium kozijn_kantoren': ['31',
#   '21'],
#  '31_WIN_WB_aluminium kozijn kantoren_4 panelen:Ae.051_aluminium kozijn_kantoren': ['31',
#   '21'],
#  '31_WIN_WB_aluminium kozijn kantoren_2 panelen:Ae.051': ['31', '21'],
#  '31_WIN_WB_aluminium kozijn kantoren_4 panelen:Ae.040_aluminium kozijn_kantoren': ['31',
#   '21'],
#  '31_WIN_WB_aluminium kozijn kantoren_4 panelen:Ae.041_aluminium kozijn_kantoren': ['31',
#   '21'],
#  '31_WIN_WB_aluminium kozijn kantoren_2 panelen:Ae.050': ['31', '21'],
#  '31_WIN_WB_aluminium kozijn kantoren_4 panelen:Ae.046_aluminium kozijn_kantoren': ['31',
#   '21'],
#  '31_WIN_WB_aluminium kozijn kantoren_2 panelen:Ae.053': ['31', '21'],
#  '31_WIN_WB_aluminium kozijn kantoren_2 panelen:Ae.042': ['31', '21'],
#  '31_WIN_WB_aluminium kozijn kantoren_2 panelen:Ae.052': ['31', '21'],
#  '32_DO_WB_kozijn curtain wall_gevel_Schuco:Kozijn curtain wall_glas_GEN_bronze': ['31',
#   '40'],
#  'Basic Roof:27_RO_isolatie EPS150': ['27', '11'],
#  '32_DO_WB_Houten deur_beton:Door_1018x2392_B60': ['32', '31'],
#  'Basic Wall:21_WA_HSB constructief': ['21', '13'],
#  '31_WIN_WB_aluminium kozijn_met spuiluik:WIN_Ae.027': ['31', '25'],
#  '31_WIN_WB_aluminium kozijn_met middenstijl:WIN_Ae.022': ['31', '25'],
#  '31_WIN_WB_aluminium kozijn_met middenstijl:WIN_Ae.026': ['31', '25'],
#  '31_WIN_WB_aluminium kozijn_met middenstijl:WIN_Ae.020': ['31', '25'],
#  '31_WIN_WB_aluminium kozijn_met spuiluik:WIN_Ae.024': ['31', '25'],
#  '31_WIN_WB_aluminium kozijn:WIN_Ae.004': ['31', '21'],
#  '31_WIN_WB_aluminium kozijn:WIN_Ae.003': ['31', '21'],
#  '31_WIN_WB_aluminium kozijn_met middenstijl:WIN_Ae.025': ['31', '25'],
#  '31_WIN_WB_aluminium kozijn_met spuiluik:WIN_Ae.028': ['31', '25'],
#  '31_WIN_WB_aluminium kozijn_met middenstijl:WIN_Ae.021': ['31', '25'],
#  '31_WIN_WB_aluminium kozijn_met middenstijl:WIN_Ae.032': ['31', '25'],
#  '31_WIN_WB_aluminium kozijn_met spuiluik:WIN_Ae.037': ['31', '25'],
#  '31_WIN_WB_aluminium kozijn:WIN_Ae.005': ['31', '21'],
#  '31_WIN_WB_aluminium kozijn_met middenstijl:WIN_Ae.030': ['31', '25'],
#  '31_WIN_WB_aluminium kozijn_met middenstijl:WIN_Ae.036': ['31', '25'],
#  '31_WIN_WB_aluminium kozijn_met spuiluik:WIN_Ae.034': ['31', '25'],
#  '31_WIN_WB_aluminium kozijn_met middenstijl:WIN_Ae.035': ['31', '25'],
#  '31_WIN_WB_aluminium kozijn_met middenstijl:WIN_Ae.031': ['31', '25'],
#  '31_WIN_WB_aluminium kozijn_met spuiluik:WIN_Ae.033': ['31', '25'],
#  '32_DO_WB_Houten deur_metalstud:Door_1018x2392_B60 S200': ['32', '31'],
#  '32_DO_WB_Houten deur_beton:Door_1218x2392': ['32', '31'],
#  '32_DO_WB_Stalen kozijn:Door_955x2400_schacht': ['32', '31'],
#  '32_DO_WB_binnendeur staal:DO_750x2630': ['32', '31'],
#  '32_DO_WB_kozijn staal binnen:Door_800x2400': ['32', '31'],
#  '32_DO_WB_kozijn staal binnen:Door_750x2400': ['32', '31'],
#  '32_DO_WB_binnendeur staal:DO_750x2780': ['32', '31'],
#  '31_WIN_WB_raam_A2_vast:A1_Entree_Mezzanine_L00-A_1725x2235': ['32', '20'],
#  '31_WIN_WB_aluminium kozijn_met middenstijl:WIN_Ae.015': ['31', '25'],
#  '31_WIN_WB_aluminium kozijn_met spuiluik:WIN_Ae.018': ['31', '25'],
#  '31_WIN_WB_aluminium kozijn_met middenstijl:WIN_Ae.010': ['31', '25'],
#  '31_WIN_WB_aluminium kozijn_met middenstijl:WIN_Ae.012': ['31', '25'],
#  '31_WIN_WB_aluminium kozijn_met spuiluik:WIN_Ae.014': ['31', '25'],
#  '31_WIN_WB_aluminium kozijn_met middenstijl:WIN_Ae.016': ['31', '25'],
#  '31_WIN_WB_aluminium kozijn:WIN_Ae.002': ['31', '21'],
#  '31_WIN_WB_aluminium kozijn:WIN_Ae.001': ['31', '21'],
#  '31_WIN_WB_aluminium kozijn_met middenstijl:WIN_Ae.011': ['31', '25'],
#  '31_WIN_WB_aluminium kozijn_met spuiluik:WIN_Ae.017': ['31', '25'],
#  '32_DO_WB_Stalen kozijn_TEC_B105:Door_1055x2400_trappenhuis': ['32', '31'],
#  '31_WIN_WB_aluminium kozijn_met spuiluik:WIN_Ae.023': ['31', '25'],
#  '31_WIN_WB_aluminium kozijn_met spuiluik:WIN_Ae.013': ['31', '25'],
#  '31_WIN_WB_aluminium kozijn_met spuiluik:WIN_Ae.038': ['31', '25'],
#  '31_WIN_WB_aluminium kozijn:WIN_Ae.007': ['31', '21'],
#  '31_WIN_WB_aluminium kozijn:WIN_Ae.006': ['31', '21'],
#  '31_WIN_WB_aluminium kozijn_met middenstijl:WIN_Ae.038': ['31', '25'],
#  '31_WIN_WB_aluminium kozijn_met middenstijl:WIN_Ae.037': ['31', '25'],
#  '32_DO_WB_Houten deur_metalstud:Door_868x2392_B00': ['32', '31'],
#  '32_DO_WB_Houten deur_dubbel_metalstud:1500x2392': ['32', '31'],
#  'Basic Wall:22_WA_MV 100/2.75': ['22', '13'],
#  '32_DO_WB_Houten deur_dubbel_metalstud:1483x2392': ['32', '31'],
#  '31_CWD': ['31', '40'],
#  'Rectangular Mullion:37_CWM_Jazo door panel mullion ': ['31', '40'],
#  '31_WIN_WB_raam_A2_vast:A1_Entree_Mezzanine_L00-A': ['32', '20'],
#  '32_DO_WB_Houten deur nood lift_beton:Door_968x2334_B60 SA': ['32', '31'],
#  '27_GM_luifel:NLRS_27.1_GM': ['27', '11'],
#  'Basic Wall:21_WA_HSB dakopstand': ['21', '13'],
#  '32_DO_WB_Houten deur_metalstud:Door_1018x2392_B00_zelfsluitend': ['32',
#   '31'],
#  '32_DO_WB': ['32', '31'],
#  '32_WIN_WB': ['32', '21'],
#  '32_GM_UN': ['32', '30'],
#  '23_GM_Loggia:23.2_GM': ['23', '22'],
#  '32_DO_WB_enkele deur met zijlicht_GEN:zij': ['32', '31'],
#  '23_FL': ['23', '22'],
#  '32_DO_WB_Houten deur_metalstud:Door_968x2392_B30': ['32', '31'],
#  'Basic Wall:22_WA_gipsplaat': ['22', '13'],
#  'Floor:21_FL_HSB onderdorpel': ['31', '00'],
#  'Floor:21_FL_vensterbank': ['21', '10'],
#  '41_GM_waterslag_natuursteen gevel:Aluminium waterslag': ['31', '00'],
#  '41_GM_waterslag_natuursteen gevel:Aluminium waterslag_hoek links': ['31',
#   '00'],
#  '41_GM_waterslag_natuursteen gevel:Aluminium waterslag_hoek rechts': ['31',
#   '00'],
#  'Basic Wall:NLRS_22.21_WA_prefab betonwand 150': ['22', '21'],
#  '31_WIN_WB_aluminium kozijn_loggia_A1:WIN_Ae.040': ['31', '25'],
#  '31_WIN_WB_aluminium kozijn_buitendeur:31_WIN_WB_aluminium kozijn': ['31',
#   '24'],
#  'Basic Roof:27_RO_hoog dak_PIR': ['27', '10'],
#  '32_DO_WB_Houten deur_dubbel_metalstud:1800x2392': ['32', '31'],
#  '56_SE_WB': ['56', '81'],
#  '32_DO_WB_Stalen kozijn:Door_1055x2400_trappenhuis': ['32', '31'],
#  '32_DO_WB_Houten deur_metalstud:Door_918x2392_B60': ['32', '31'],
#  '32_DO_WB_Houten deur_metalstud:Door_968x2392_B00': ['32', '31'],
#  'Basic Wall:22_WA_MS 75/1.50.1.A': ['22', '13'],
#  '32_DO_WB_Houten deur_metalstud:Door_718x2392_B00': ['32', '31'],
#  'Basic Wall:22_WA_Hout': ['22', '11'],
#  '32_DO_WB_Stalen deur_techniek buiten:32_DO_WB_Stalen deur': ['31', '31'],
#  '31_DO': ['31', '40'],
#  '32_DO_WB_Houten deur_beton:Door_1018x2392_B30': ['32', '31'],
#  'Basic Wall:21_WA_sandwichpaneel': ['21', '13'],
#  '31_WIN_WB_B2_aluminium kozijn:WIN_Ae.005_1650x2506': ['31', '25'],
#  '31_WIN_WB_aluminium kozijn_met spuiluik:WIN_Ae.013_2400x2506': ['31', '25'],
#  '31_WIN_WB_B2_aluminium kozijn:WIN_Ae.006_2400x2506': ['31', '25'],
#  '31_WIN_WB_B2_aluminium kozijn:WIN_Ae.005_2510x2506': ['31', '25'],
#  '32_DO_WB_houten woningvoordeur_metalstud:Door_1064x2410_woningentreedeur_B30': ['32',
#   '31'],
#  '31_WIN_WB_B2_aluminium kozijn:WIN_Ae.008_2428x1860': ['31', '25'],
#  '31_WIN_WB_B2_aluminium kozijn:WIN_Ae.006_2428x2410': ['31', '25'],
#  '31_WIN_WB_B2_aluminium kozijn:WIN_Ae.007_2414x1750': ['31', '25'],
#  '31_WIN_WB_B2_aluminium kozijn:WIN_Ae.007_2428x1750': ['31', '25'],
#  '31_WIN_WB_B2_aluminium kozijn:WIN_Ae.005_2428x2410': ['31', '25'],
#  '': ['31', '20'],
#  'Rectangular Mullion:37.20 CWM Schuco 264.5x60': ['21', '14'],
#  'Basic Wall:22_WA_prefab betonwand': ['22', '11'],
#  '32_DO_WB_Houten deur_metalstud:Door_918x2592_B60': ['32', '31'],
#  '31_WIN_WB_aluminium kozijn_met middenstijl:WIN_Ae.010_2446x1650': ['31',
#   '25'],
#  '31_WIN_WB_aluminium kozijn_met spuiluik:WIN_Ae.013_2446x1650': ['31', '25'],
#  '31_WIN_WB_B2_aluminium kozijn:WIN_Ae.005_1660x2083': ['31', '25'],
#  '31_WIN_WB_B2_aluminium kozijn:WIN_Ae.005_2400x2083': ['31', '25'],
#  '31_WIN_WB_B2_aluminium kozijn:WIN_Ae.005_2510x2083': ['31', '25'],
#  '32_WIN_WB_raam_A2_terrace:A2_O/W_L03a': ['32', '20'],
#  '31_WIN_WB_aluminium kozijn_met middenstijl:WIN_Ae.011_2420x2810': ['31',
#   '25'],
#  '31_WIN_WB_aluminium kozijn_met middenstijl:WIN_Ae.011_1745x2810': ['31',
#   '25'],
#  '31_WIN_WB_aluminium kozijn_met middenstijl:WIN_Ae.011_1855x2810': ['31',
#   '25'],
#  '31_WIN_WB_aluminium kozijn_met middenstijl:WIN_Ae.011_1855x2810_deur': ['31',
#   '25'],
#  '32_DO_WB_binnendeur staal:DO_950x2630': ['32', '31'],
#  '32_DO_WB_binnendeur staal:DO_750x3130': ['32', '31'],
#  '32_DO_WB_binnendeur staal:DO_1000x3130': ['32', '31'],
#  'Basic Wall:22_WA_MV 75/2.50.A': ['22', '13'],
#  '32_DO_WB_Houten deur_beton:Door_1018x2592': ['32', '31'],
#  '32_DO_WB_Houten deur_beton:Door_1018x2592_B60': ['32', '31'],
#  '32_DO_WB_binnendeur staal_badkamer:DO_1000x2630': ['32', '31'],
#  '31_WIN_WB_aluminium kozijn_met middenstijl:WIN_Ae.010_2506x1650': ['31',
#   '25'],
#  '31_WIN_WB_aluminium kozijn_met spuiluik:WIN_Ae.013_2506x1650': ['31', '25'],
#  '23_GM_Balkon': ['23', '12'],
#  '32_DO_WB_PRS deur enkel beglaasd_gen': ['32', '30'],
#  '32_GM_UN_clash object_gen': ['32', '30'],
#  '31_WIN_WB_aluminium kozijn_met middenstijl:WIN_Ae.012_1855x2810': ['31',
#   '25'],
#  '32_DO_WB_binnendeur staal:DO_800x3130': ['32', '31'],
#  'Basic Wall:21_WA_beton ihwg': ['21', '11'],
#  '31_WIN_WB_aluminium kozijn_met middenstijl:WIN_Ae.011_2520x2810': ['31',
#   '25'],
#  '32_DO_WB_binnendeur staal_zonder bovenlicht:DO_1000x2393': ['32', '31'],
#  '32_DO_WB_Houten deur_dubbel_metalstud:1554x2392': ['32', '31'],
#  'Basic Wall:22_WA_MV 100/ 2.75.A': ['22', '13'],
#  '32_DO_WB_kozijn curtain wall_buiten draaiend_Schuco:Kozijn curtain wall_glas_GEN': ['21',
#   '14'],
#  '31_WIN_WB_aluminium kozijn_loggia:WIN_Ae.004': ['31', '21'],
#  '31_WIN_WB_aluminium kozijn loggia_met spuiluik:WIN_Ae.013_2470x2535_loggia': ['31',
#   '25'],
#  'Floor:21_FL_stelkozijn': ['21', '13'],
#  'Basic Wall:22_WA_Fermacell': ['22', '13'],
#  '31_WIN_WB_B2_aluminium kozijn:WIN_Ae.008_2414x1860': ['31', '25'],
#  '31_WIN_WB_B2_aluminium kozijn:WIN_Ae.006_2414x2410': ['31', '25'],
#  '31_WIN_WB_B2_aluminium kozijn:WIN_Ae.005_2414x2410': ['31', '25'],
#  '31_WIN_WB_aluminium kozijn loggia_met spuiluik:WIN_Ae.014_2455x2535_loggia': ['31',
#   '25'],
#  '32_DO_WB_Houten deur_beton:Door_1018x2592_B30': ['32', '31'],
#  '31_WIN_WB_B2_aluminium kozijn:WIN_Ae.007_2390x1750': ['31', '25'],
#  '31_WIN_WB_B2_aluminium kozijn:WIN_Ae.008_2390x1860': ['31', '25'],
#  '31_WIN_WB_B2_aluminium kozijn:WIN_Ae.006_2390x2410': ['31', '25'],
#  '31_WIN_WB_B2_aluminium kozijn:WIN_Ae.005_2390x2410': ['31', '25'],
#  '32_DO_WB_binnendeur staal_zonder bovenlicht:DO_800x2400': ['32', '31'],
#  '32_DO_WB_binnendeur staal_zonder bovenlicht:DO_1000x2400': ['32', '31'],
#  '31_GM_waterslag A2_vl01_03:31_waterslag': ['31', '20'],
#  '31_GM_waterslag A2_vl01_03:31_waterslag_ksl': ['31', '20'],
#  '31_GM_waterslag A2_vl01_03:31_waterslag_ksr': ['31', '20'],
#  '31_GM_waterslag A2_vl01_03:31_waterslag_loggia_ksr': ['31', '20'],
#  '31_GM_waterslag A2_vl01_03:31_waterslag_loggia': ['31', '20'],
#  '31_GM_waterslag A2_vl01_03:31_waterslag_penant': ['31', '20'],
#  'Floor:21_FL_Multiplex': ['21', '13'],
#  '31_WIN_WB_aluminium kozijn_met middenstijl:WIN_Ae.011_2520x2256': ['31',
#   '25'],
#  '31_WIN_WB_aluminium kozijn_met middenstijl:WIN_Ae.011_2420x2256': ['31',
#   '25'],
#  '31_WIN_WB_aluminium kozijn_met middenstijl:WIN_Ae.012_1745x2256': ['31',
#   '25'],
#  '31_WIN_WB_aluminium kozijn_met middenstijl:WIN_Ae.013_1855x2256': ['31',
#   '25'],
#  '31_WIN_WB_aluminium kozijn_met middenstijl:WIN_Ae.011_1855x2256': ['31',
#   '25'],
#  '31_WIN_WB_aluminium kozijn_met middenstijl:WIN_Ae.012_1855x2256': ['31',
#   '25'],
#  'Basic Wall:90_WA_ privacy scherm': ['31', '40'],
#  'Rectangular Mullion:Privacy Screen': ['31', '40'],
#  '32_DO_WB_Houten kozijn:Door': ['32', '31'],
#  '32_DO_WB_kozijn staal binnen1:Door_800x2400': ['32', '31'],
#  '32_DO_WB_kozijn staal binnen1:Door_750x2400': ['32', '31'],
#  '32_DO_WB_Houten deur_metalstud:Door_1018x2392_E20': ['32', '31'],
#  'Basic Wall:21_WA_isolatie': ['21', '10'],
#  'Basic Wall:21_WA_kantenplank': ['21', '10'],
#  '32_DO_WB_Houten deur_metalstud:Door_718x2392_B60': ['32', '31'],
#  '32_DO_WB_binnen kozijn staal:DO_1000x2620': ['32', '31'],
#  '32_DO_WB_houten woningvoordeur_beton:Door_1064x2410_woningentreedeur': ['32',
#   '31'],
#  '32_DO_WB_binnen kozijn staal:DO_800x2620': ['32', '31'],
#  '32_DO_WB_binnen kozijn staal:DO_800x3120': ['32', '31'],
#  '32_DO_WB_binnen kozijn staal:DO_1000x3120': ['32', '31'],
#  '32_DO_WB_houten woningvoordeur_metalstud:Door_1064x2410_woningentreedeur': ['32',
#   '31'],
#  '32_DO_WB_Houten deur_beton_omgekeerd profiel:Door_1018x2392_E20': ['32',
#   '31'],
#  '32_DO_WB_binnen kozijn staal zonder bovenlicht:Door_800x2400': ['32', '31'],
#  '32_DO_WB_binnen kozijn staal zonder bovenlicht:Door_1000x2400': ['32', '31'],
#  '32_DO_WB_Houten deur_dubbel_metalstud:1834x2592': ['32', '31'],
#  '31_WIN_WB_aluminium kozijn_met middenstijl:WIN_Ae.022_2710x1860': ['31',
#   '25'],
#  '31_WIN_WB_aluminium kozijn_met middenstijl:WIN_Ae.020_2710x1970': ['31',
#   '25'],
#  '31_WIN_WB_aluminium kozijn_met middenstijl:WIN_Ae.021_2246x1860': ['31',
#   '25'],
#  '31_WIN_WB_aluminium kozijn_met middenstijl:WIN_Ae.016_2246x1970': ['31',
#   '25'],
#  'Basic Wall:21_WA_prefab betonwand': ['21', '11'],
#  '31_WIN_WB_Alumn kozijn_11de verd:WIN_Ae.002': ['31', '25'],
#  '32_DO_WB_binnen kozijn staal:DO_750x2620': ['32', '31'],
#  '32_DO_WB_binnen kozijn staal:DO_750x3120': ['32', '31'],
#  '32_DO_WB_binnen kozijn staal zonder bovenlicht:Door_750x2400': ['32', '31'],
#  'Floor:23_FL_isolatie EPS': ['23', '10'],
#  '32_DO_WB_profielstalen enkele deur met zijlicht links:pui woningentree 1385X2700': ['32',
#   '31'],
#  'NLRS_32.30_D_PRS deur enkel beglaasd_gen': ['32', '30'],
#  'NLRS_32.30_GM_UN_clash object_gen': ['32', '30'],
#  'Basic Wall:21_WA_isolatie + HSB_235mm': ['21', '10'],
#  '32_DO_WB_brandwerend scherm_Hoefnagels_Fire_Safety_Firescreen_Flame_F:HB_Firescreen_Flame_F2': ['32',
#   '32'],
#  '41_B2_PFB YY.SN.2:41_B2': ['21', '11'],
#  '41_B2_PFB YY.SN.1c:41_B2': ['21', '11'],
#  '41_B2_PFB YY.SN.5:41_B2': ['21', '11'],
#  '41_B2_PFB YY.SN.6:41_B2': ['21', '11'],
#  '41_B2_PFB YY.SN.1:41_B2': ['21', '11'],
#  '41_B2_PFB YY.SD.4:41_B2': ['21', '21'],
#  '21_B2_PFB 03.SN.4:41_B2': ['21', '11'],
#  '21_B2_PFB 03.SN.7:41_B2': ['21', '11'],
#  '41_B2_PFB YY.SD.1:41_B2': ['21', '21'],
#  '41_B2_PFB YY.SD.2:41_B2': ['21', '21'],
#  '41_B2_PFB YY.SN.3:41_B2': ['21', '11'],
#  '21_B2_PFB 04.SD.5:41_B2': ['21', '21'],
#  '21_B2_PFB 04.SN.8:41_B2': ['21', '11'],
#  '21_B2_PFB 00.K.5:41_B2': ['21', '11'],
#  '21_B2_PFB 00.K.4:41_B2': ['21', '11'],
#  '21_B2_PFB 00.H.1:41_B2': ['21', '11'],
#  '21_B2_PFB 00.H.2:41_B2': ['21', '11'],
#  '21_B2_PFB 00.K.1:41_B2': ['21', '11'],
#  '21_B2_PFB 00.K.6:41_B2': ['21', '11'],
#  '21_B2_PFB 00.K.3:41_B2': ['21', '11'],
#  '21_B2_PFB 00.K.2:41_B2': ['21', '11'],
#  '41_B2_PFB YY.H.3:41_B2': ['21', '11'],
#  '41_B2_PFB YY.L.10:41_B2': ['21', '11'],
#  '21_B2_PFB 01.L.9:41_B2': ['21', '11'],
#  '41_B2_PFB YY.SD.3:41_B2': ['21', '21'],
#  '21_B2_PFB 11.DR.1:41_B2': ['21', '11'],
#  '21_B2_PFB 11.DR.3:41_B2': ['21', '11'],
#  '21_B2_PFB 11.DR.2:41_B2': ['21', '11'],
#  '21_B2_PFB 00.BN.3:41_B2': ['21', '11'],
#  '21_B2_PFB 00.BN.3c:41_B2': ['21', '11'],
#  '21_B2_PFB 00.BN.4:41_B2': ['21', '11'],
#  '21_B2_PFB 00.BD.1:41_B2': ['21', '21'],
#  '21_B2_PFB 00.BN.2:41_B2': ['21', '11'],
#  '21_B2_PFB 0M.BD.1:41_B2': ['21', '21'],
#  '21_B2_PFB 0M.BN.1:41_B2': ['21', '11'],
#  '21_B2_PFB 0M.BN.2:41_B2': ['21', '11'],
#  '21_B2_PFB 0M.BN.4:41_B2': ['21', '11'],
#  '21_B2_PFB 0M.L.1:41_B2': ['21', '11'],
#  '21_B2_PFB 0M.L.2:41_B2': ['21', '11'],
#  '21_B2_PFB 0M.L.8:41_B2': ['21', '11'],
#  '21_B2_PFB 0M.L.3:41_B2': ['21', '11'],
#  '21_B2_PFB 0M.L.4:41_B2': ['21', '11'],
#  '21_B2_PFB 0M.L.7:41_B2': ['21', '11'],
#  '21_B2_PFB 0M.L.5:41_B2': ['21', '11'],
#  '21_B2_PFB 0M.L.6:41_B2': ['21', '11'],
#  '31_WIN_WB_B2_aluminium kozijn:WIN_Ae.004': ['31', '25'],
#  '31_WIN_WB_B2_aluminium kozijn:WIN_Ae.005': ['31', '25'],
#  '31_WIN_WB_B2_aluminium kozijn:WIN_Ae.006': ['31', '25'],
#  '21_B2_PFB 00.BN.1:41_B2': ['21', '11'],
#  '31_WIN_WB_B2_aluminium kozijn:WIN_Ae.007': ['31', '25'],
#  '31_WIN_WB_B2_aluminium kozijn:WIN_Ae.008': ['31', '25'],
#  '31_WIN_WB_B2_aluminium kozijn:WIN_Ae.009': ['31', '25'],
#  '31_WIN_WB_B2_aluminium kozijn:WIN_Ae.010': ['31', '25'],
#  '31_WIN_WB_B2_aluminium kozijn:WIN_Ae.011': ['31', '25'],
#  '21_B2_PFB 00.K.7:41_B2': ['21', '11'],
#  '31_WIN_WB_B2_aluminium kozijn_klein:WIN_Ae.012': ['31', '25'],
#  '31_WIN_WB_B2_aluminium kozijn_klein:WIN_Ae.013': ['31', '25'],
#  '31_WIN_WB_B2_aluminium kozijn_klein:WIN_Ae.014': ['31', '25'],
#  '31_WIN_WB_aluminium kozijn_met middenstijl:WIN_Ae.015_2246x1970': ['31',
#   '25'],
#  '31_WIN_WB_aluminium kozijn_met middenstijl:WIN_Ae.028_2246x1970': ['31',
#   '25'],
#  '31_WIN_WB_aluminium kozijn_met middenstijl:WIN_Ae.019_2246x1970': ['31',
#   '25'],
#  '31_WIN_WB_aluminium kozijn_met middenstijl:WIN_Ae.027_2246x1860': ['31',
#   '25'],
#  '31_WIN_WB_aluminium kozijn_met middenstijl:WIN_Ae.018_2710x1970': ['31',
#   '25'],
#  '31_WIN_WB_aluminium kozijn_met gevelrooster:WIN_Ae.018_2710x1970': ['31',
#   '25'],
#  '31_WIN_WB_aluminium kozijn_met gevelrooster:WIN_Ae.017_2710x1970': ['31',
#   '25'],
#  '31_WIN_WB_aluminium kozijn_met middenstijl:WIN_Ae.026_2710x1970': ['31',
#   '25'],
#  '31_WIN_WB_aluminium kozijn_met middenstijl:WIN_Ae.023_2710x1860': ['31',
#   '25'],
#  '31_WIN_WB_aluminium kozijn_met middenstijl:WIN_Ae.024_2710x1970': ['31',
#   '25'],
#  '31_WIN_WB_aluminium kozijn_met middenstijl:WIN_Ae.017_2710x1970': ['31',
#   '25'],
#  'System Panel:31_CWP': ['21', '14'],
#  'CW_sandwich paneel vliesgevel:CW_sandwich paneel vliesgevel': ['21', '14'],
#  'CW_sandwich paneel vliesgevel:21_CWP': ['21', '14'],
#  'Rectangular Mullion:37.20 CWM Schuco 250x60': ['21', '14'],
#  '32_B2_dorpel pui_dak verdieping:32_B2_dorpel pui': ['32', '41'],
#  '32_DO_WB_Houten deur_beton:Door_1018x2342_B30': ['32', '31'],
#  'Basic Wall:22_WA': ['22', '11'],
#  'Basic Wall:22_WA_kalkzandsteen gen': ['22', '11'],
#  '32_DO_WB_Houten deur_metalstud:Door_1018x2392_B60': ['32', '31'],
#  '32_DO_WB_Houten deur_metalstud:Door_1018x2392_B60_glas': ['32', '31'],
#  '32_DO_WB_Houten deur_beton:Door_1018x2392_B60_glas': ['32', '31'],
#  '32_DO_WB_Houten deur_dubbel_metalstud:1818x2392_B00': ['32', '31'],
#  '32_DO_WB_Houten deur_metalstud:Door_1018x2392_B30_glas': ['32', '31'],
#  '32_DO_WB_Houten deur_beton:Door_1018x2392_B30_glas': ['32', '31'],
#  '32_DO_WB_Houten deur_metalstud:Door_1018x2392_B00_glas_thermisch': ['32',
#   '31'],
#  'Basic Wall:21_WA_isolatie gen': ['21', '10'],
#  'Basic Wall:22_WA_prefab betonwand gen': ['22', '21'],
#  '32_DO_WB_Houten kozijn dubbele deur:32_DO_WKO': ['32', '31'],
#  '32_DO_WB_Houten deur_dubbel_metalstud_bovenlicht:1818x2192': ['32', '31'],
#  '32_DO_WB_Houten deur_metalstud:Door_1318x2392': ['32', '31'],
#  'Basic Wall:22_WA_MS-wand 157.5mm_105min': ['22', '13'],
#  'Floor:23_FL_beton prefab plaat gen': ['23', '21'],
#  '32_WIN_rooster 1300x2000:32_WIN': ['32', '21'],
#  '32_DO_WB_Houten deur_dubbel_metalstud:1730x2392_B00': ['32', '31'],
#  '32_DO_WB_Houten deur_dubbel_metalstud:1730x2392_B60': ['32', '31'],
#  '32_DO_WB_Houten deur_beton:Door_1018x1880': ['32', '31'],
#  'NLRS_32.31_DO_WB_kozijn avento-RZ_GEN:Avento_RZ_WK2': ['32', '31'],
#  'NLRS_32.31_DO_WB_kozijn avento-RZ_GEN:Avento_RZ_WK2_1005x2360': ['32', '31'],
#  'NLRS_32.31_DO_WB_kozijn avento-RZ_GEN:Avento_RZ_60+': ['32', '31'],
#  'NLRS_32.31_DO_WB_kozijn avento-RZ-202_GEN:Avento_RZ_202': ['32', '31'],
#  'NLRS_32.31_DO_WB_kozijn avento-RZ-202_GEN:Avento_RZ_60+_202': ['32', '31'],
#  'NLRS_32.31_DO_WB_kozijn avento-RZ_GEN:Avento_RZ_60+_1005x2360': ['32', '31'],
#  'Floor:NLRS_13.10_FL': ['13', '10'],
#  'NLRS_32.31_DO_WB_kozijn berlengo-RZ_GEN:Berlengo_RZ_1010x2610_p100_B00': ['32',
#   '31'],
#  'NLRS_32.31_DO_WB_plaatstalen dubbele deur_GEN:Staalkozijn_vlak_1810x2390': ['32',
#   '31'],
#  'NLRS_32.31_DO_WB_plaatstalen enkele deur_GEN:Staalkozijn_vlak_RZ_1000x2370': ['32',
#   '31'],
#  'Basic Roof:27_dak opbouwen': ['27', '10'],
#  'NLRS_32.31_DO_WB_kozijn berlengo-RZ_GEN:Berlengo_RZ_1010x2607_p100': ['32',
#   '31'],
#  'Basic Wall:21_glaswand': ['21', '10'],
#  'NLRS_32.31_DO_WB_kozijn berlengo-RZ_GEN:Berlengo_RZ_1010x2392_p100_B00': ['32',
#   '31'],
#  'NLRS_32.31_DO_WB_kozijn Berdo-RL_GEN:Berdo_RL_1002x2605_p100': ['32', '31'],
#  'NLRS_32.31_DO_WB_kozijn Berdo-RL_GEN:Berdo_RL_902x2602_p100': ['32', '31'],
#  'NLRS_32.31_DO_WB_kozijn Berdo-RL_GEN:Berdo_RL_1002x2602_p100': ['32', '31'],
#  'NLRS_32.31_DO_WB_kozijn Berdo-RL_GEN:Berdo_RL_1002x2602_p100_B00': ['32',
#   '31'],
#  'NLRS_32.31_DO_WB_kozijn berlengo-RZ_GEN:Berlengo_RZ_1010x2607_p100_B00': ['32',
#   '31'],
#  'NLRS_32.31_DO_WB_jonkakast dubbel': ['32', '31'],
#  'NLRS_32.31_DO_WB_kozijn berlengo-RZ_GEN:Berlengo_RZ_910x2607_p100': ['32',
#   '31'],
#  'NLRS_32.31_DO_WB_kozijn berlengo-RZ-202_GEN:Berlengo_RZ-200_1666x2607_p100_B00': ['32',
#   '31'],
#  'NLRS_32.31_DO_WB_kozijn berlengo-RL_GEN:Berlengo_RL_1010x2610_p100_B00': ['32',
#   '31'],
#  'NLRS_32.31_DO_WB_kozijn berlengo-RL_GEN:Berlengo_RL_1010x2607_p100': ['32',
#   '31'],
#  'NLRS_32.31_DO_WB_jonkakast enkel_GEN:jonkakast': ['32', '31'],
#  'NLRS_32.31_DO_WB_jonkakast dubbel_GEN:jonkakast': ['32', '31'],
#  'NLRS_32.31_DO_WB_kozijn berlengo-RZ-202_GEN:Berlengo_RZ-200_1466x2607_p100_B00': ['32',
#   '31'],
#  'NLRS_32.31_DO_WB_kozijn berlengo-RZ_GEN:Berlengo_RZ_1010x2379_p100': ['32',
#   '31'],
#  'NLRS_32.31_DO_WB_kozijn berlengo-RZ-202_GEN:Berlengo_RZ-200_1466x2379_p100_B00': ['32',
#   '31'],
#  'NLRS_32.31_DO_WB_kozijn berlengo-RZ_GEN:Berlengo_RZ_1010x2379_p100_B00': ['32',
#   '31'],
#  'NLRS_31.00_WI_WB_aluprof_GEN:WI_klein raam': ['31', '10'],
#  'NLRS_31.00_WI_WB_aluprof balkondeur GEN:WI_deur naar balkon': ['31', '10'],
#  'NLRS_31.00_WI_WB_aluprof 2 delen:balkon pui gesloten': ['31', '10'],
#  'NLRS_31.00_WI_WB_aluprof_GEN:WI_klein raam_gesloten': ['31', '10'],
#  'NLRS_31.00_WI_WB_aluprof_GEN:WI_klein raam_open': ['31', '10'],
#  'NLRS_31.00_WI_WB_aluprof 2 delen:1_kantelraam': ['31', '10'],
#  'NLRS_31.00_WI_WB_aluprof balkondeur GEN:WI_deur naar balkon 4e': ['31',
#   '10'],
#  'NLRS_31.00_WI_WB_aluprof 2 delen:1': ['31', '10'],
#  'NLRS_31.00_WI_WB_aluprof 2 delen:1_raam': ['31', '10'],
#  'NLRS_31.00_WI_WB_aluprof 2 delen:dicht': ['31', '10'],
#  'NLRS_31.00_WI_WB_aluprof 2 delen:balkon pui gesloten 4e_2410 ': ['31', '10'],
#  'NLRS_31.00_WI_WB_aluprof_GEN:WI': ['31', '10'],
#  'NLRS_31.00_DO_WB_aluprof_GEN:raam_tweedelig': ['31', '10'],
#  'NLRS_31.00_DO_WB_aluprof_GEN:raam': ['31', '10'],
#  'NLRS_31.00_DO_WB_aluprof_GEN:aldowa': ['31', '10'],
#  'NLRS_31.00_DO_WB_aluprof deur fietsenstalling:raam_1 deur': ['31', '30'],
#  'NLRS_32.31_DO_WB_kozijn hout enkele deur_GEN:Hout_glas_RZ_1110x2390': ['32',
#   '31'],
#  'NLRS_32.31_DO_WB_kozijn Berdo-RL-202_GEN:Berdo_RL_202_1458x2351_p100': ['32',
#   '31'],
#  'Basic Wall:49_WA': ['16', '00'],
#  'Floor:NLRS_43.10_FL': ['16', '00'],
#  'NLRS_31.00_WI_WB_aluprof_verdekt kozijn:kozijn': ['31', '10'],
#  'Basic Wall:21_WA': ['21', '10'],
#  'Basic Roof:27_hoog dak': ['27', '10'],
#  'NLRS_32.31_DO_WB_kozijn berlengo-RZ-202_GEN:Berlengo_RZ-200_1466x2607_p100': ['32',
#   '31'],
#  'NLRS_32.31_DO_WB_kozijn berlengo-RL-202_GEN:Berlengo_RL-200_1466x2607_p100': ['32',
#   '31'],
#  'NLRS_32.31_DO_WB_kozijn berlengo-RZ_GEN:Berlengo_RZ_990rx2610_p100_B00': ['32',
#   '31'],
#  'NLRS_31.00_WI_WB_aluprof_verdekt kozijn:kozijn_verdekt kozijn': ['31', '10'],
#  'NLRS_32.31_DO_WB_plaatstalen dubbele deur_GEN:Staalkozijn_vlak_1810x2390_B60': ['32',
#   '31'],
#  'Basic Wall:21': ['21', '10'],
#  'Floor:NLRS_13.10_FL_halfsteens_grijs': ['13', '10'],
#  'Rectangular Mullion:RSen_21_CWM_support profile - 50x50 - left_gen': ['21',
#   '10'],
#  'Rectangular Mullion:RSen_21_CWM_support profile - 50x50 - right_gen': ['21',
#   '10'],
#  'Basic Wall:RSen_21_WA_louvre blade classic W 50-75Z_gen': ['21', '10'],
#  'Basic Roof:00 schachtkap': ['27', '10'],
#  'NLRS_32.31_DO_WB_kozijn berlengo-RL_GEN:Berlengo_RL_910x2607_p100': ['32',
#   '31'],
#  'NLRS_32.31_DO_WB_kozijn avento-RZ_GEN:Avento_RZ_60+ WK2': ['32', '31'],
#  'NLRS_32.31_DO_WB_kozijn hout enkele deur_GEN:Hout_vlak_RZ_60+_1110x2390': ['32',
#   '31'],
#  '31_WI_vliesgevelpui_aluprof_met deur:raam balkon_b2460_h2390': ['31', '30'],
#  '31_WI_vliesgevelpui_aluprof_met deur:raam balkon_b2725': ['31', '30'],
#  '31_WI_vliesgevelpui_aluprof_met deur:raam balkon_h2390_b2425': ['31', '30'],
#  '31_WI_vliesgevelpui_aluprof_met deur:raam balkon_h2390_b2750': ['31', '30'],
#  '31_WI_vliesgevelpui_aluprof_met deur:raam balkon_h2390_b2435': ['31', '30'],
#  '31_WI_vliesgevelpui_aluprof_met deur:raam balkon_2460': ['31', '30'],
#  '31_WI_vliesgevelpui_aluprof_enkel': ['31', '30'],
#  '31_WI_vliesgevelpui_aluprof_met deur:raam balkon_2425': ['31', '30'],
#  '31_WI_vliesgevelpui_aluprof_met deur:raam balkon_2750': ['31', '30'],
#  '31_WI_vliesgevelpui_aluprof_met deur:raam balkon_2435': ['31', '30'],
#  '31_WI_vliesgevelpui_aluprof_met deur:raam_balkon': ['31', '30'],
#  '31_WI_vliesgevelpui_aluprof_met deur:1 deur': ['31', '30'],
#  '31_WI_vliesgevelpui_aluprof_met deur:raam_balkon_2460': ['31', '30'],
#  'NLRS_32.31_DO_WB_kozijn staal enkele deur met zijlicht_GEN:Staalkozijn_zij_1640x2390': ['32',
#   '31'],
#  'NLRS_57.00': ['57', '00'],
#  'NLRS_32.31_DO_WB_profielstalen enkele deur_GEN:PRS_1030x2365': ['32', '31'],
#  'Floor:DUMMY_vloer': ['23', '99'],
#  'NLRS_32.31_DO_WB_profielstalen dubbele deur 2x zijlicht_GEN:PRS_2710x2400': ['32',
#   '31'],
#  'NLRS_32-20_WI_WB_raam 2x_gen_KAAN:PRS_2684x2720': ['32', '20'],
#  'NLRS_32.99_GM_UN_door swing clash object': ['32', '99'],
#  'NLRS_23.22_GM_LB_balkon_prefab_GEN:NLRS_23.22_GM_LB_balkon_prefab': ['23',
#   '22'],
#  'NLRS_23.22_GM_LB_balkon_prefab_BA2_GEN:NLRS_23.22_GM_LB_balkon_prefab_BA2': ['23',
#   '22'],
#  'NLRS_31.00_WI_WB': ['31', '10'],
#  'NLRS_31.00_DO_WB': ['31', '10'],
#  'NLRS_32.32_GM_WB': ['32', '32'],
#  'Curtain Panel5:Curtain Panel': ['31', '20'],
#  'Curtain Panel3:Curtain Panel': ['31', '20'],
#  'Curtain Panel1:Curtain Panel': ['31', '20'],
#  'Rectangular Mullion:50x214 entree': ['31', '20'],
#  'NLRS_32.32_DO': ['31', '32'],
#  'Basic Wall:00 KAAN constructiewand_250': ['28', '00'],
#  'NLRS_32.31_DO_WB_kozijn berlengo-RZ-202_GEN:Berlengo_RZ-200_1946x2607_p100': ['32',
#   '31'],
#  '57.10_GM_FB_ducogrille solid': ['57', '10'],
#  'Curtain Panel11:Curtain Panel': ['31', '20'],
#  'Curtain Panel10:Curtain Panel': ['31', '20'],
#  'Curtain Panel9:Curtain Panel': ['31', '20'],
#  'Basic Wall:22_WA_inspectieluik': ['22', '10'],
#  'Basic Wall:22_WA_voorzetwand keuken': ['22', '13'],
#  'NLRS_32.00_WI_WB_inspectieluik:NLRS_32.00_WI_WB': ['32', '20'],
#  'NLRS_32.00_WI_WB_inspectieluik:600x600mm': ['32', '20'],
#  'NLRS_32.31_DO_WB_kozijn Daloc S43_GEN1:Daloc_S43_990x2370': ['32', '31'],
#  'Basic Wall:22_WA_voorzetwand inbouw': ['22', '13']}

# %%
columns = [
    "Product Ref",
    "Product Name",
    "Selected",
    "Element ID",
    "Element Ref",
    "Element Name",
    "Element Environmental Score",
    "Element Description",
]
data = []
for n, r in product_references.items():
    if r[0] in element_types_dict:
        row = [".".join(r), n] + ([""] * 5)
        data.append(row)
        for e in element_types_dict[r[0]]:
            row = ([""] * 3) + [
                e["id"],
                e["reference"],
                e["names"]["en"],
                e["environmentalCost"],
                e["description"]["en"],
            ]
            data.append(row)

# %%
df = pd.DataFrame(data, columns=columns)

# %%
df
# Out:
#       Product Ref                                      Product Name Selected  \
# 0           22.00  Basic Wall:K_20_WA_GF pigmented wall placeholder
# 1
# 2
# 3
# 4
# ...           ...                                               ...      ...
# 30434
# 30435
# 30436
# 30437
# 30438
#
#       Element ID Element Ref                               Element Name  \
# 0
# 1       ET304850     (22.8)+     PW_Hollow bricks_Fired clay_LIB_New_01
# 2       ET304851     (22.8)+       PW_Hollow blocks_Concrete_LIB_New_01
# 3       ET304852     (22.8)+      PW_Hollow bricks_Sand-lime_LIB_New_01
# 4       ET304853     (22.8)+                PW_Blocks_Gypsum_LIB_New_01
# ...          ...         ...                                        ...
# 30434   ET305145     (22.1)+   Lblw_Solid bricks_Fired clay_LIB_Reno_01
# 30435   ET305146     (22.1)+   Lblw_Solid bricks_Fired clay_LIB_Reno_02
# 30436   ET305147     (22.3)+          nLblW_Blocks_Hempcrete_LIB_new_01
# 30437   ET305148     (22.3)+  nLblW_Solid Bricks_Fired clay_LIB_Reno_01
# 30438   ET305149     (22.3)+  nLblW_Solid Bricks_Fired clay_LIB_Reno_02
#
#       Element Environmental Score  \
# 0
# 1                         9.45191
# 2                         8.79372
# 3                         17.7362
# 4                         4.88114
# ...                           ...
# 30434                     0.95254
# 30435                    0.642323
# 30436                     3.50401
# 30437                     1.67243
# 30438                     1.25315
#
#                                      Element Description
# 0                                                   None
# 1      Thick coating_Gypsum plaster | Hollow bricks_F...
# 2      Thick coating_Gypsum plaster | Hollow blocks_C...
# 3      Rigid tiles_Glazed ceramic | Hollow bricks_San...
# 4      Blocks_Gypsum (501x100x666 mm) | Blanket_Stone...
# ...                                                  ...
# 30434  Thick coating_Gypsum plaster | Solid bricks_Fi...
# 30435  Thick coating_Clay plaster | Solid bricks_Fire...
# 30436  Thick coating_Clay plaster | Blocks_Hempcrete ...
# 30437  Thick coating_Gypsum plaster | Solid bricks_Fi...
# 30438  Thick coating_Clay plaster | Solid bricks_Fire...
#
# [30439 rows x 8 columns]

# %%
df.to_csv(Path("totem_mapping.csv"), index=False)
